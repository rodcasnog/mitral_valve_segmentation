# %% [markdown]
# # Task 3: Helper notebook for loading the data and saving the predictions

# %%
import pickle
import gzip

# %% [markdown]
# ### Helper functions

# %%
def load_zipped_pickle(filename):
    with gzip.open(filename, 'rb') as f:
        loaded_object = pickle.load(f)
        return loaded_object

# %%
def save_zipped_pickle(obj, filename):
    with gzip.open(filename, 'wb') as f:
        pickle.dump(obj, f, 2)

# %% [markdown]
# ### Load data, make predictions and save prediction in correct format

# %%
# load data
train_data = load_zipped_pickle("train.pkl")
test_data = load_zipped_pickle("test.pkl")
samples = load_zipped_pickle("sample.pkl")

# %%
from matplotlib import pyplot as plt
from IPython.display import clear_output
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
IMG_SIZE = max(max(set(d['box'].shape[0] for d in train_data)), max(set(d['box'].shape[1] for d in train_data))) //64*64 // 2

IMG_SIZE = (IMG_SIZE, IMG_SIZE)
print(IMG_SIZE)

directory = '/Users/rcasado/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/AML/task3/images_big'
directory_only_expert = '/Users/rcasado/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/AML/task3/images_only_expert'
# Out:
# (416, 416)

# %%
from keras.preprocessing.image import ImageDataGenerator

rotation_range = 15
width_shift_range = 0.15
height_shift_range = 0.15
shear_range = 0.15
zoom_range = 0.1
seed = 1
sigma = .5

batch_size = 16

def preprocessing_function(x):
    # x = elasticdeform.deform_random_grid(x, points=6, sigma=sigma, axis=(0, 1))
    x = (x / 255. - 0.5) * 2.
    return x

def preprocessing_function_label(x):
    x = (x/255.).astype(np.bool_).reshape(IMG_SIZE[0], IMG_SIZE[1], 1)
    return x

def obtain_datagenerator(directory, preprocessing_function, batch_size=batch_size, seed=seed, rotation_range=rotation_range, width_shift_range=width_shift_range, height_shift_range=height_shift_range, shear_range=shear_range, zoom_range=zoom_range, IMG_SIZE=IMG_SIZE):

    datagen = ImageDataGenerator(
        rotation_range=rotation_range,
        width_shift_range=width_shift_range,
        height_shift_range=height_shift_range,
        shear_range=shear_range,
        zoom_range=zoom_range,
        preprocessing_function=preprocessing_function,
    )

    generator = datagen.flow_from_directory(
        directory,
        target_size=IMG_SIZE,
        batch_size=batch_size,
        color_mode='grayscale',
        class_mode=None,
        seed = seed,
    )

    return generator

def obtain_test_datagenerator(directory, preprocessing_function, IMG_SIZE=IMG_SIZE):

    datagen = ImageDataGenerator(
        preprocessing_function=preprocessing_function,
    )

    generator = datagen.flow_from_directory(
        directory,
        target_size=IMG_SIZE,
        batch_size=batch_size,
        color_mode='grayscale',
        class_mode=None,
        seed = seed,
    )

    return generator

# %%
# TRAIN
# IMAGES
train_generator = obtain_datagenerator(directory + '/train/train', preprocessing_function)

# LABELS
train_mask_generator = obtain_datagenerator(directory + '/train/train_label', preprocessing_function_label)

# # BOXES
# train_box_generator = obtain_datagenerator(directory + '/train/train_box', preprocessing_function_label)

# VAL
# IMAGES
val_generator = obtain_datagenerator(directory + '/val/train', preprocessing_function)

# LABELS
val_mask_generator = obtain_datagenerator(directory + '/val/train_label', preprocessing_function_label)

# BOXES
val_box_generator = obtain_datagenerator(directory + '/val/train_box', preprocessing_function_label)

# TEST
# IMAGES
test_generator = obtain_test_datagenerator(directory + '/test/train', preprocessing_function)

# LABELS
test_mask_generator = obtain_test_datagenerator(directory + '/test/train_label', preprocessing_function_label)

# BOXES
test_box_generator = obtain_test_datagenerator(directory + '/test/train_box', preprocessing_function_label)

# TRAIN_ALL
# IMAGES
train_all_generator = obtain_datagenerator(directory + '/all/train', preprocessing_function)

# LABELS
train_all_mask_generator = obtain_datagenerator(directory + '/all/train_label', preprocessing_function_label)

# # BOXES
# train_all_box_generator = obtain_datagenerator(directory + '/all/train_box', preprocessing_function_label)
# Out:
# Found 156 images belonging to 1 classes.
# Found 156 images belonging to 1 classes.
# Found 39 images belonging to 1 classes.
# Found 39 images belonging to 1 classes.
# Found 39 images belonging to 1 classes.
# Found 3685 images belonging to 1 classes.
# Found 0 images belonging to 1 classes.
# Found 0 images belonging to 1 classes.
# Found 195 images belonging to 1 classes.
# Found 195 images belonging to 1 classes.

# %%
def my_image_mask_generator(image_data_generator, mask_data_generator):
    for (img, mask) in zip(image_data_generator, mask_data_generator):
        yield (img, mask)

# %%
train_batches = my_image_mask_generator(train_generator, train_mask_generator)

val_batches = my_image_mask_generator(val_generator, val_mask_generator)

train_all_batches = my_image_mask_generator(train_all_generator, train_all_mask_generator)

# %%
# TRAIN_EXPERT
# IMAGES
train_only_expert_generator = obtain_datagenerator(directory_only_expert + '/train/train', preprocessing_function)

# LABELS
train_only_expert_mask_generator = obtain_datagenerator(directory_only_expert + '/train/train_label', preprocessing_function_label)

# # BOXES
# train_only_expert_box_generator = obtain_datagenerator(directory_only_expert + '/train/train_box', preprocessing_function_label)

# VAL_EXPERT
# IMAGES
val_only_expert_generator = obtain_datagenerator(directory_only_expert + '/val/train', preprocessing_function)

# LABELS
val_only_expert_mask_generator = obtain_datagenerator(directory_only_expert + '/val/train_label', preprocessing_function_label)

# BOXES
# val_only_expert_box_generator = obtain_datagenerator(directory_only_expert + '/val/train_box', preprocessing_function_label)

# TRAIN_ALL_EXPERT
# IMAGES
train_all_only_expert_generator = obtain_datagenerator(directory_only_expert + '/all/train', preprocessing_function)

# LABELS
train_all_only_expert_mask_generator = obtain_datagenerator(directory_only_expert + '/all/train_label', preprocessing_function_label)

# # BOXES
# train_all_only_expert_box_generator = obtain_datagenerator(directory_only_expert + '/all/train_box', preprocessing_function_label)
# Out:
# Found 48 images belonging to 1 classes.
# Found 48 images belonging to 1 classes.
# Found 9 images belonging to 1 classes.
# Found 9 images belonging to 1 classes.
# Found 57 images belonging to 1 classes.
# Found 57 images belonging to 1 classes.

# %%
train_only_expert_batches = my_image_mask_generator(train_only_expert_generator, train_only_expert_mask_generator)

val_only_expert_batches = my_image_mask_generator(val_only_expert_generator, val_only_expert_mask_generator)

train_all_only_expert_batches = my_image_mask_generator(train_all_only_expert_generator, train_all_only_expert_mask_generator)

# %%
from IPython.display import clear_output
import time
a = next(train_batches)
for i in range(batch_size):
    plt.imshow(a[0][i] + 2*a[1][i], cmap='hot', vmin=-1, vmax=3)
    plt.show()
    clear_output(wait=True)
    time.sleep(.5)

# %% [markdown]
# # MODEL

# %%
dropout = .25

# %%
def double_conv_block(x, n_filters):

   x = layers.Conv2D(n_filters, 3, padding = "same", activation = "linear", kernel_initializer = "he_normal")(x)
   x = layers.BatchNormalization()(x)
   x = layers.Activation("relu")(x)
   x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)

   return x

# %%
def downsample_block(x, n_filters):
   
   f = double_conv_block(x, n_filters)
   p = layers.MaxPool2D(2, strides=2)(f)
   p = layers.BatchNormalization()(p)
   p = layers.Dropout(dropout)(p)

   return f, p

# %%
def upsample_block(x, conv_features, n_filters):
   
   x = layers.Conv2DTranspose(n_filters, 3, 2, padding="same", activation="linear")(x)
   x = layers.BatchNormalization()(x)
   x = layers.Activation("relu")(x)
   x = layers.concatenate([x, conv_features])
   x = layers.Dropout(dropout)(x)
   x = double_conv_block(x, n_filters)

   return x

# %%
def build_unet_model():
    
    inputs = layers.Input(shape=IMG_SIZE + (1,))

    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(inputs, 32)
    # 2 - downsample
    f2, p2 = downsample_block(p1, 64)
    # 3 - downsample
    f3, p3 = downsample_block(p2, 128)
    # 4 - downsample
    f4, p4 = downsample_block(p3, 256)
    # 4 - downsample
    f5, p5 = downsample_block(p4, 512)

    # 5 - bottleneck
    bottleneck = double_conv_block(p5, 1024)

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f5, 512)
    # 7 - upsample
    u7 = upsample_block(u6, f4, 256)
    # 8 - upsample
    u8 = upsample_block(u7, f3, 128)
    # 9 - upsample
    u9 = upsample_block(u8, f2, 64)
    # 10 - upsample
    u10 = upsample_block(u9, f1, 32)

    # outputs
    outputs = layers.Conv2D(1, 1, padding="same", activation = "sigmoid")(u10)

    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

    return unet_model

unet_model = build_unet_model()

# %% [markdown]
# dropout = .65

# %% [markdown]
# def build_unet_model():
#
#     inputs = layers.Input(shape=IMG_SIZE + (1,))
#
#     # encoder: contracting path - downsample
#     # 1 - downsample
#     f1, p1 = downsample_block(inputs, 128)
#     # 2 - downsample
#     f2, p2 = downsample_block(p1, 512)
#     # 3 - downsample
#     f3, p3 = downsample_block(p2, 1024)
#
#     # 5 - bottleneck
#     bottleneck = double_conv_block(p3, 2048)
#
#     # decoder: expanding path - upsample
#     # 6 - upsample
#     u6 = upsample_block(bottleneck, f3, 1024)
#     # 7 - upsample
#     u7 = upsample_block(u6, f2, 512)
#     # 8 - upsample
#     u8 = upsample_block(u7, f1, 128)
#
#     # outputs
#     outputs = layers.Conv2D(1, 1, padding="same", activation = "sigmoid")(u8)
#
#     # unet model with Keras Functional API
#     unet_model = tf.keras.Model(inputs, outputs, name="U-Net")
#
#     return unet_model
#
# unet_model = build_unet_model()

# %%
print(unet_model.summary())
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 416, 416, 1)]        0         []
#
#  conv2d_69 (Conv2D)          (None, 416, 416, 32)         320       ['input_4[0][0]']
#
#  batch_normalization_63 (Ba  (None, 416, 416, 32)         128       ['conv2d_69[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 416, 416, 32)         0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  conv2d_70 (Conv2D)          (None, 416, 416, 32)         9248      ['activation_48[0][0]']
#
#  max_pooling2d_15 (MaxPooli  (None, 208, 208, 32)         0         ['conv2d_70[0][0]']
#  ng2D)
#
#  batch_normalization_64 (Ba  (None, 208, 208, 32)         128       ['max_pooling2d_15[0][0]']
#  tchNormalization)
#
#  dropout_30 (Dropout)        (None, 208, 208, 32)         0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  conv2d_71 (Conv2D)          (None, 208, 208, 64)         18496     ['dropout_30[0][0]']
#
#  batch_normalization_65 (Ba  (None, 208, 208, 64)         256       ['conv2d_71[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 208, 208, 64)         0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  conv2d_72 (Conv2D)          (None, 208, 208, 64)         36928     ['activation_49[0][0]']
#
#  max_pooling2d_16 (MaxPooli  (None, 104, 104, 64)         0         ['conv2d_72[0][0]']
#  ng2D)
#
#  batch_normalization_66 (Ba  (None, 104, 104, 64)         256       ['max_pooling2d_16[0][0]']
#  tchNormalization)
#
#  dropout_31 (Dropout)        (None, 104, 104, 64)         0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  conv2d_73 (Conv2D)          (None, 104, 104, 128)        73856     ['dropout_31[0][0]']
#
#  batch_normalization_67 (Ba  (None, 104, 104, 128)        512       ['conv2d_73[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 104, 104, 128)        0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  conv2d_74 (Conv2D)          (None, 104, 104, 128)        147584    ['activation_50[0][0]']
#
#  max_pooling2d_17 (MaxPooli  (None, 52, 52, 128)          0         ['conv2d_74[0][0]']
#  ng2D)
#
#  batch_normalization_68 (Ba  (None, 52, 52, 128)          512       ['max_pooling2d_17[0][0]']
#  tchNormalization)
#
#  dropout_32 (Dropout)        (None, 52, 52, 128)          0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  conv2d_75 (Conv2D)          (None, 52, 52, 256)          295168    ['dropout_32[0][0]']
#
#  batch_normalization_69 (Ba  (None, 52, 52, 256)          1024      ['conv2d_75[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 52, 52, 256)          0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  conv2d_76 (Conv2D)          (None, 52, 52, 256)          590080    ['activation_51[0][0]']
#
#  max_pooling2d_18 (MaxPooli  (None, 26, 26, 256)          0         ['conv2d_76[0][0]']
#  ng2D)
#
#  batch_normalization_70 (Ba  (None, 26, 26, 256)          1024      ['max_pooling2d_18[0][0]']
#  tchNormalization)
#
#  dropout_33 (Dropout)        (None, 26, 26, 256)          0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  conv2d_77 (Conv2D)          (None, 26, 26, 512)          1180160   ['dropout_33[0][0]']
#
#  batch_normalization_71 (Ba  (None, 26, 26, 512)          2048      ['conv2d_77[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 26, 26, 512)          0         ['batch_normalization_71[0][0]
#                                                                     ']
#
#  conv2d_78 (Conv2D)          (None, 26, 26, 512)          2359808   ['activation_52[0][0]']
#
#  max_pooling2d_19 (MaxPooli  (None, 13, 13, 512)          0         ['conv2d_78[0][0]']
#  ng2D)
#
#  batch_normalization_72 (Ba  (None, 13, 13, 512)          2048      ['max_pooling2d_19[0][0]']
#  tchNormalization)
#
#  dropout_34 (Dropout)        (None, 13, 13, 512)          0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  conv2d_79 (Conv2D)          (None, 13, 13, 1024)         4719616   ['dropout_34[0][0]']
#
#  batch_normalization_73 (Ba  (None, 13, 13, 1024)         4096      ['conv2d_79[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 13, 13, 1024)         0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  conv2d_80 (Conv2D)          (None, 13, 13, 1024)         9438208   ['activation_53[0][0]']
#
#  conv2d_transpose_15 (Conv2  (None, 26, 26, 512)          4719104   ['conv2d_80[0][0]']
#  DTranspose)
#
#  batch_normalization_74 (Ba  (None, 26, 26, 512)          2048      ['conv2d_transpose_15[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 26, 26, 512)          0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  concatenate_15 (Concatenat  (None, 26, 26, 1024)         0         ['activation_54[0][0]',
#  e)                                                                  'conv2d_78[0][0]']
#
#  dropout_35 (Dropout)        (None, 26, 26, 1024)         0         ['concatenate_15[0][0]']
#
#  conv2d_81 (Conv2D)          (None, 26, 26, 512)          4719104   ['dropout_35[0][0]']
#
#  batch_normalization_75 (Ba  (None, 26, 26, 512)          2048      ['conv2d_81[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 26, 26, 512)          0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  conv2d_82 (Conv2D)          (None, 26, 26, 512)          2359808   ['activation_55[0][0]']
#
#  conv2d_transpose_16 (Conv2  (None, 52, 52, 256)          1179904   ['conv2d_82[0][0]']
#  DTranspose)
#
#  batch_normalization_76 (Ba  (None, 52, 52, 256)          1024      ['conv2d_transpose_16[0][0]']
#  tchNormalization)
#
#  activation_56 (Activation)  (None, 52, 52, 256)          0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  concatenate_16 (Concatenat  (None, 52, 52, 512)          0         ['activation_56[0][0]',
#  e)                                                                  'conv2d_76[0][0]']
#
#  dropout_36 (Dropout)        (None, 52, 52, 512)          0         ['concatenate_16[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 52, 52, 256)          1179904   ['dropout_36[0][0]']
#
#  batch_normalization_77 (Ba  (None, 52, 52, 256)          1024      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  activation_57 (Activation)  (None, 52, 52, 256)          0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  conv2d_84 (Conv2D)          (None, 52, 52, 256)          590080    ['activation_57[0][0]']
#
#  conv2d_transpose_17 (Conv2  (None, 104, 104, 128)        295040    ['conv2d_84[0][0]']
#  DTranspose)
#
#  batch_normalization_78 (Ba  (None, 104, 104, 128)        512       ['conv2d_transpose_17[0][0]']
#  tchNormalization)
#
#  activation_58 (Activation)  (None, 104, 104, 128)        0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  concatenate_17 (Concatenat  (None, 104, 104, 256)        0         ['activation_58[0][0]',
#  e)                                                                  'conv2d_74[0][0]']
#
#  dropout_37 (Dropout)        (None, 104, 104, 256)        0         ['concatenate_17[0][0]']
#
#  conv2d_85 (Conv2D)          (None, 104, 104, 128)        295040    ['dropout_37[0][0]']
#
#  batch_normalization_79 (Ba  (None, 104, 104, 128)        512       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_59 (Activation)  (None, 104, 104, 128)        0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 104, 104, 128)        147584    ['activation_59[0][0]']
#
#  conv2d_transpose_18 (Conv2  (None, 208, 208, 64)         73792     ['conv2d_86[0][0]']
#  DTranspose)
#
#  batch_normalization_80 (Ba  (None, 208, 208, 64)         256       ['conv2d_transpose_18[0][0]']
#  tchNormalization)
#
#  activation_60 (Activation)  (None, 208, 208, 64)         0         ['batch_normalization_80[0][0]
#                                                                     ']
#
#  concatenate_18 (Concatenat  (None, 208, 208, 128)        0         ['activation_60[0][0]',
#  e)                                                                  'conv2d_72[0][0]']
#
#  dropout_38 (Dropout)        (None, 208, 208, 128)        0         ['concatenate_18[0][0]']
#
#  conv2d_87 (Conv2D)          (None, 208, 208, 64)         73792     ['dropout_38[0][0]']
#
#  batch_normalization_81 (Ba  (None, 208, 208, 64)         256       ['conv2d_87[0][0]']
#  tchNormalization)
#
#  activation_61 (Activation)  (None, 208, 208, 64)         0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  conv2d_88 (Conv2D)          (None, 208, 208, 64)         36928     ['activation_61[0][0]']
#
#  conv2d_transpose_19 (Conv2  (None, 416, 416, 32)         18464     ['conv2d_88[0][0]']
#  DTranspose)
#
#  batch_normalization_82 (Ba  (None, 416, 416, 32)         128       ['conv2d_transpose_19[0][0]']
#  tchNormalization)
#
#  activation_62 (Activation)  (None, 416, 416, 32)         0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  concatenate_19 (Concatenat  (None, 416, 416, 64)         0         ['activation_62[0][0]',
#  e)                                                                  'conv2d_70[0][0]']
#
#  dropout_39 (Dropout)        (None, 416, 416, 64)         0         ['concatenate_19[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 416, 416, 32)         18464     ['dropout_39[0][0]']
#
#  batch_normalization_83 (Ba  (None, 416, 416, 32)         128       ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_63 (Activation)  (None, 416, 416, 32)         0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  conv2d_90 (Conv2D)          (None, 416, 416, 32)         9248      ['activation_63[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 416, 416, 1)          33        ['conv2d_90[0][0]']
#
# ==================================================================================================
# Total params: 34605729 (132.01 MB)
# Trainable params: 34595745 (131.97 MB)
# Non-trainable params: 9984 (39.00 KB)
# __________________________________________________________________________________________________
# None

# %%
# Set the seed using keras.utils.set_random_seed. This will set:
# 1) `numpy` seed
# 2) backend random seed
# 3) `python` random seed
keras.utils.set_random_seed(seed)

# %%
def scheduler(epoch, lr):
    if epoch % 30 == 0 and epoch != 0:
        return lr / 10
    else:
        return lr

callback = keras.callbacks.LearningRateScheduler(scheduler)

# %%
IMG_SIZE
# Out:
# (416, 416)

# %%
unet_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])#, keras.metrics.MeanIoU(num_classes=2)])

NUM_EPOCHS = 50

STEPS_PER_EPOCH = (165 // batch_size) * 5
VALIDATION_STEPS = (39 // batch_size) + 1

model_history = unet_model.fit(train_all_batches,
                              epochs=NUM_EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              validation_steps=VALIDATION_STEPS,
                              callbacks=[callback],
                              validation_data=val_batches)

unet_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(1e-4),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])#, keras.metrics.MeanIoU(num_classes=2)])

NUM_EPOCHS = 30

STEPS_PER_EPOCH = (165 // batch_size) * 2

model_history2 = unet_model.fit(train_only_expert_batches,
                              epochs=NUM_EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              validation_steps=VALIDATION_STEPS,
                              callbacks=[callback],
                              validation_data=val_only_expert_batches)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 37s 703ms/step - loss: 0.0912 - accuracy: 0.9715 - val_loss: 2.5519 - val_accuracy: 0.9878 - lr: 0.0010
# Epoch 2/50
# 50/50 [==============================] - 32s 640ms/step - loss: 0.0225 - accuracy: 0.9895 - val_loss: 0.1811 - val_accuracy: 0.9881 - lr: 0.0010
# Epoch 3/50
# 50/50 [==============================] - 31s 625ms/step - loss: 0.0181 - accuracy: 0.9894 - val_loss: 0.0574 - val_accuracy: 0.9896 - lr: 0.0010
# Epoch 4/50
# 50/50 [==============================] - 31s 622ms/step - loss: 0.0165 - accuracy: 0.9894 - val_loss: 0.0227 - val_accuracy: 0.9879 - lr: 0.0010
# Epoch 5/50
# 50/50 [==============================] - 31s 620ms/step - loss: 0.0159 - accuracy: 0.9894 - val_loss: 0.0301 - val_accuracy: 0.9881 - lr: 0.0010
# Epoch 6/50
# 50/50 [==============================] - 32s 631ms/step - loss: 0.0151 - accuracy: 0.9893 - val_loss: 0.0201 - val_accuracy: 0.9881 - lr: 0.0010
# Epoch 7/50
# 20/20 [==============================] - 14s 705ms/step - loss: 0.0045 - accuracy: 0.9982 - val_loss: 0.0061 - val_accuracy: 0.9976 - lr: 1.0000e-04
# Epoch 26/30
# 20/20 [==============================] - 14s 712ms/step - loss: 0.0045 - accuracy: 0.9982 - val_loss: 0.0061 - val_accuracy: 0.9975 - lr: 1.0000e-04
# Epoch 27/30
# 20/20 [==============================] - 14s 712ms/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 0.0062 - val_accuracy: 0.9975 - lr: 1.0000e-04
# Epoch 28/30
# 20/20 [==============================] - 14s 713ms/step - loss: 0.0043 - accuracy: 0.9983 - val_loss: 0.0060 - val_accuracy: 0.9976 - lr: 1.0000e-04
# Epoch 29/30
# 20/20 [==============================] - 14s 707ms/step - loss: 0.0043 - accuracy: 0.9983 - val_loss: 0.0064 - val_accuracy: 0.9975 - lr: 1.0000e-04
# Epoch 30/30
# 20/20 [==============================] - 14s 714ms/step - loss: 0.0044 - accuracy: 0.9983 - val_loss: 0.0064 - val_accuracy: 0.9974 - lr: 1.0000e-04

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(model_history.history['accuracy']+model_history2.history['accuracy'])
plt.plot(model_history.history['val_accuracy']+model_history2.history['val_accuracy'])
plt.yscale('log')
plt.grid()
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(model_history.history['loss']+model_history2.history['loss'])
plt.plot(model_history.history['val_loss']+model_history2.history['val_loss'])
plt.yscale('log')
plt.grid()
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
unet_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(1e-4),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])#, keras.metrics.MeanIoU(num_classes=2)])

NUM_EPOCHS = 20

STEPS_PER_EPOCH = (165 // batch_size) * 2
VALIDATION_STEPS = (39 // batch_size) + 1

model_history = unet_model.fit(train_only_expert_batches,
                              epochs=NUM_EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              validation_steps=VALIDATION_STEPS,
                              validation_data=val_only_expert_batches)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 15s 681ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0159 - val_accuracy: 0.9954
# Epoch 2/20
# 20/20 [==============================] - 13s 666ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0235 - val_accuracy: 0.9946
# Epoch 3/20
# 20/20 [==============================] - 13s 665ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0234 - val_accuracy: 0.9943
# Epoch 4/20
# 20/20 [==============================] - 13s 672ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0204 - val_accuracy: 0.9948
# Epoch 5/20
# 20/20 [==============================] - 13s 673ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0207 - val_accuracy: 0.9948
# Epoch 6/20
# 20/20 [==============================] - 13s 674ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0245 - val_accuracy: 0.9943
# Epoch 7/20
# 20/20 [==============================] - 13s 673ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0208 - val_accuracy: 0.9952
# Epoch 8/20
# 20/20 [==============================] - 13s 673ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.0252 - val_accuracy: 0.9940
# Epoch 9/20
# 20/20 [==============================] - 13s 671ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0201 - val_accuracy: 0.9951
# Epoch 10/20
# 20/20 [==============================] - 13s 675ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0263 - val_accuracy: 0.9938
# Epoch 11/20
# 20/20 [==============================] - 14s 684ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0268 - val_accuracy: 0.9938
# Epoch 12/20
# 20/20 [==============================] - 13s 674ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0222 - val_accuracy: 0.9949
# Epoch 13/20
# 20/20 [==============================] - 13s 675ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0233 - val_accuracy: 0.9946
# Epoch 14/20
# 20/20 [==============================] - 13s 672ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.0225 - val_accuracy: 0.9947
# Epoch 15/20
# 20/20 [==============================] - 13s 670ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0196 - val_accuracy: 0.9952
# Epoch 16/20
# 20/20 [==============================] - 13s 667ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0184 - val_accuracy: 0.9953
# Epoch 17/20
# 20/20 [==============================] - 13s 669ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0188 - val_accuracy: 0.9950
# Epoch 18/20
# 20/20 [==============================] - 13s 667ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.0216 - val_accuracy: 0.9953
# Epoch 19/20
# 20/20 [==============================] - 13s 669ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0217 - val_accuracy: 0.9950
# Epoch 20/20
# 20/20 [==============================] - 13s 670ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.0220 - val_accuracy: 0.9947

# %%
NUM_EPOCHS = 70

STEPS_PER_EPOCH = (165 // batch_size) * 5
VALIDATION_STEPS = 1

model_history = unet_model.fit(train_batches,
                              epochs=NUM_EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              validation_steps=VALIDATION_STEPS,
                              callbacks=[callback],
                              validation_data=val_batches)


unet_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(1e-4),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])#, keras.metrics.MeanIoU(num_classes=2)])

NUM_EPOCHS = 30

STEPS_PER_EPOCH = (165 // batch_size) * 2

model_history = unet_model.fit(train_only_expert_batches,
                              epochs=NUM_EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              validation_steps=VALIDATION_STEPS,
                              callbacks=[callback],
                              validation_data=val_only_expert_batches)
# Out:
# Epoch 18/50
# 20/20 [==============================] - 14s 679ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.0226 - val_accuracy: 0.9945 - lr: 1.0000e-04
# Epoch 19/50
# 20/20 [==============================] - 14s 677ms/step - loss: 0.0036 - accuracy: 0.9984 - val_loss: 0.0152 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 20/50
# 20/20 [==============================] - 13s 675ms/step - loss: 0.0036 - accuracy: 0.9985 - val_loss: 0.0223 - val_accuracy: 0.9946 - lr: 1.0000e-04
# Epoch 21/50
# 20/20 [==============================] - 13s 675ms/step - loss: 0.0036 - accuracy: 0.9985 - val_loss: 0.0157 - val_accuracy: 0.9953 - lr: 1.0000e-04
# Epoch 22/50
# 20/20 [==============================] - 14s 677ms/step - loss: 0.0036 - accuracy: 0.9985 - val_loss: 0.0148 - val_accuracy: 0.9957 - lr: 1.0000e-04
# Epoch 23/50
# 20/20 [==============================] - 13s 672ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.0214 - val_accuracy: 0.9945 - lr: 1.0000e-04
# Epoch 24/50
# 20/20 [==============================] - 13s 670ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.0208 - val_accuracy: 0.9951 - lr: 1.0000e-04
# Epoch 25/50
# 20/20 [==============================] - 13s 672ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.0200 - val_accuracy: 0.9950 - lr: 1.0000e-04
# Epoch 26/50
# 20/20 [==============================] - 13s 671ms/step - loss: 0.0034 - accuracy: 0.9985 - val_loss: 0.0209 - val_accuracy: 0.9948 - lr: 1.0000e-04
# Epoch 27/50
# 20/20 [==============================] - 13s 671ms/step - loss: 0.0034 - accuracy: 0.9985 - val_loss: 0.0170 - val_accuracy: 0.9954 - lr: 1.0000e-04
# Epoch 28/50
#  1/20 [>.............................] - ETA: 12s - loss: 0.0036 - accuracy: 0.9984
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rcasado/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/AML/task3/training more res.ipynb Cell 31 line 1
#       <a href='vscode-notebook-cell:/Users/rcasado/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual%20Studio%20Code/AML/task3/training%20more%20res.ipynb#Y123sZmlsZQ%3D%3D?line=6'>7</a> STEPS_PER_EPOCH = (165 // batch_size) * 2
#       <a href='vscode-notebook-cell:/Users/rcasado/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual%20Studio%20Code/AML/task3/training%20more%20res.ipynb#Y123sZmlsZQ%3D%3D?line=7'>8</a> VALIDATION_STEPS = 1
# ---> <a href='vscode-notebook-cell:/Users/rcasado/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual%20Studio%20Code/AML/task3/training%20more%20res.ipynb#Y123sZmlsZQ%3D%3D?line=9'>10</a> model_history = unet_model.fit(train_only_expert_batches,
#      <a href='vscode-notebook-cell:/Users/rcasado/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual%20Studio%20Code/AML/task3/training%20more%20res.ipynb#Y123sZmlsZQ%3D%3D?line=10'>11</a>                               epochs=NUM_EPOCHS,
#      <a href='vscode-notebook-cell:/Users/rcasado/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual%20Studio%20Code/AML/task3/training%20more%20res.ipynb#Y123sZmlsZQ%3D%3D?line=11'>12</a>                               steps_per_epoch=STEPS_PER_EPOCH,
#      <a href='vscode-notebook-cell:/Users/rcasado/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual%20Studio%20Code/AML/task3/training%20more%20res.ipynb#Y123sZmlsZQ%3D%3D?line=12'>13</a>                               validation_steps=VALIDATION_STEPS,
#      <a href='vscode-notebook-cell:/Users/rcasado/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual%20Studio%20Code/AML/task3/training%20more%20res.ipynb#Y123sZmlsZQ%3D%3D?line=13'>14</a>                               callbacks=[callback],
#      <a href='vscode-notebook-cell:/Users/rcasado/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual%20Studio%20Code/AML/task3/training%20more%20res.ipynb#Y123sZmlsZQ%3D%3D?line=14'>15</a>                               validation_data=val_only_expert_batches)
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/keras/src/engine/training.py:1813, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1811 logs = tmp_logs
#    1812 end_step = step + data_handler.step_increment
# -> 1813 callbacks.on_train_batch_end(end_step, logs)
#    1814 if self.stop_training:
#    1815     break
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/keras/src/callbacks.py:475, in CallbackList.on_train_batch_end(self, batch, logs)
#     468 """Calls the `on_train_batch_end` methods of its callbacks.
#     469
#     470 Args:
#     471     batch: Integer, index of batch within the current epoch.
#     472     logs: Dict. Aggregated metric results up until this batch.
#     473 """
#     474 if self._should_call_train_batch_hooks:
# --> 475     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/keras/src/callbacks.py:322, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     320     self._call_batch_begin_hook(mode, batch, logs)
#     321 elif hook == "end":
# --> 322     self._call_batch_end_hook(mode, batch, logs)
#     323 else:
#     324     raise ValueError(
#     325         f"Unrecognized hook: {hook}. "
#     326         'Expected values are ["begin", "end"]'
#     327     )
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/keras/src/callbacks.py:345, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     342     batch_time = time.time() - self._batch_start_time
#     343     self._batch_times.append(batch_time)
# --> 345 self._call_batch_hook_helper(hook_name, batch, logs)
#     347 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     348     end_hook_name = hook_name
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/keras/src/callbacks.py:393, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     391 for callback in self.callbacks:
#     392     hook = getattr(callback, hook_name)
# --> 393     hook(batch, logs)
#     395 if self._check_timing:
#     396     if hook_name not in self._hook_times:
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/keras/src/callbacks.py:1093, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1092 def on_train_batch_end(self, batch, logs=None):
# -> 1093     self._batch_update_progbar(batch, logs)
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/keras/src/callbacks.py:1169, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1165     self.seen += add_seen
#    1167 if self.verbose == 1:
#    1168     # Only block async when verbose = 1.
# -> 1169     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1170     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/keras/src/utils/tf_utils.py:694, in sync_to_numpy_or_python_type(tensors)
#     691         return t
#     692     return t.item() if np.ndim(t) == 0 else t
# --> 694 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/tensorflow/python/util/nest.py:631, in map_structure(func, *structure, **kwargs)
#     545 @tf_export("nest.map_structure")
#     546 def map_structure(func, *structure, **kwargs):
#     547   """Creates a new structure by applying `func` to each atom in `structure`.
#     548
#     549   Refer to [tf.nest](https://www.tensorflow.org/api_docs/python/tf/nest)
#    (...)
#     629     ValueError: If wrong keyword arguments are provided.
#     630   """
# --> 631   return nest_util.map_structure(
#     632       nest_util.Modality.CORE, func, *structure, **kwargs
#     633   )
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1066, in map_structure(modality, func, *structure, **kwargs)
#     969 """Creates a new structure by applying `func` to each atom in `structure`.
#     970
#     971 - For Modality.CORE: Refer to
#    (...)
#    1063   ValueError: If wrong keyword arguments are provided.
#    1064 """
#    1065 if modality == Modality.CORE:
# -> 1066   return _tf_core_map_structure(func, *structure, **kwargs)
#    1067 elif modality == Modality.DATA:
#    1068   return _tf_data_map_structure(func, *structure, **kwargs)
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1106, in _tf_core_map_structure(func, *structure, **kwargs)
#    1101 flat_structure = (_tf_core_flatten(s, expand_composites) for s in structure)
#    1102 entries = zip(*flat_structure)
#    1104 return _tf_core_pack_sequence_as(
#    1105     structure[0],
# -> 1106     [func(*x) for x in entries],
#    1107     expand_composites=expand_composites,
#    1108 )
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1106, in <listcomp>(.0)
#    1101 flat_structure = (_tf_core_flatten(s, expand_composites) for s in structure)
#    1102 entries = zip(*flat_structure)
#    1104 return _tf_core_pack_sequence_as(
#    1105     structure[0],
# -> 1106     [func(*x) for x in entries],
#    1107     expand_composites=expand_composites,
#    1108 )
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/keras/src/utils/tf_utils.py:687, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     684 def _to_single_numpy_or_python_type(t):
#     685     # Don't turn ragged or sparse tensors to NumPy.
#     686     if isinstance(t, tf.Tensor):
# --> 687         t = t.numpy()
#     688     # Strings, ragged and sparse tensors don't have .item(). Return them
#     689     # as-is.
#     690     if not isinstance(t, (np.ndarray, np.generic)):
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:394, in _EagerTensorBase.numpy(self)
#     371 """Copy of the contents of this Tensor into a NumPy array or scalar.
#     372
#     373 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#     391     NumPy dtype.
#     392 """
#     393 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 394 maybe_arr = self._numpy()  # pylint: disable=protected-access
#     395 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.conda/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:360, in _EagerTensorBase._numpy(self)
#     358 def _numpy(self):
#     359   try:
# --> 360     return self._numpy_internal()
#     361   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#     362     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.yscale('log')
plt.grid()
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.yscale('log')
plt.grid()
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
# big one, with all data

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.yscale('log')
plt.grid()
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.yscale('log')
plt.grid()
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
# big one, with only train, not all

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.yscale('log')
plt.grid()
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.yscale('log')
plt.grid()
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.yscale('log')
plt.grid()
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.yscale('log')
plt.grid()
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
def build_unet_model():
    
    inputs = layers.Input(shape=IMG_SIZE + (1,))

    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(inputs, 64)
    # 2 - downsample
    f2, p2 = downsample_block(p1, 128)
    # 3 - downsample
    f3, p3 = downsample_block(p2, 256)

    # 5 - bottleneck
    bottleneck = double_conv_block(p3, 512)

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f3, 256)
    # 7 - upsample
    u7 = upsample_block(u6, f2, 128)
    # 8 - upsample
    u8 = upsample_block(u7, f1, 64)

    # outputs
    outputs = layers.Conv2D(1, 1, padding="same", activation = "sigmoid")(u8)

    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

    return unet_model

unet_model = build_unet_model()

# %%
NUM_EPOCHS = 150

STEPS_PER_EPOCH = (165 // batch_size) * 5
VALIDATION_STEPS = 1

model_history = unet_model.fit(train_batches,
                              epochs=NUM_EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              validation_steps=VALIDATION_STEPS,
                            #   callbacks=[callback],
                              validation_data=val_batches)
# Out:
# Epoch 1/150
# 2023-12-15 09:12:26.902521: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 25/25 [==============================] - 11s 256ms/step - loss: 0.1185 - accuracy: 0.9545 - val_loss: 0.6844 - val_accuracy: 0.9849
# Epoch 2/150
# 25/25 [==============================] - 5s 186ms/step - loss: 0.0300 - accuracy: 0.9875 - val_loss: 0.1354 - val_accuracy: 0.9854
# Epoch 3/150
# 25/25 [==============================] - 5s 185ms/step - loss: 0.0214 - accuracy: 0.9913 - val_loss: 0.1317 - val_accuracy: 0.9252
# Epoch 4/150
# 25/25 [==============================] - 5s 190ms/step - loss: 0.0184 - accuracy: 0.9927 - val_loss: 0.1296 - val_accuracy: 0.9301
# Epoch 5/150
# 25/25 [==============================] - 5s 187ms/step - loss: 0.0163 - accuracy: 0.9935 - val_loss: 0.0518 - val_accuracy: 0.9743
# Epoch 6/150
# 25/25 [==============================] - 5s 185ms/step - loss: 0.0149 - accuracy: 0.9940 - val_loss: 0.0230 - val_accuracy: 0.9908
# 25/25 [==============================] - 5s 183ms/step - loss: 0.0051 - accuracy: 0.9978 - val_loss: 0.0216 - val_accuracy: 0.9936
# Epoch 144/150
# 25/25 [==============================] - 4s 183ms/step - loss: 0.0050 - accuracy: 0.9978 - val_loss: 0.0203 - val_accuracy: 0.9939
# Epoch 145/150
# 25/25 [==============================] - 5s 183ms/step - loss: 0.0050 - accuracy: 0.9978 - val_loss: 0.0223 - val_accuracy: 0.9932
# Epoch 146/150
# 25/25 [==============================] - 5s 182ms/step - loss: 0.0049 - accuracy: 0.9978 - val_loss: 0.0214 - val_accuracy: 0.9937
# Epoch 147/150
# 25/25 [==============================] - 5s 184ms/step - loss: 0.0050 - accuracy: 0.9978 - val_loss: 0.0222 - val_accuracy: 0.9937
# Epoch 148/150
# 25/25 [==============================] - 5s 185ms/step - loss: 0.0050 - accuracy: 0.9978 - val_loss: 0.0202 - val_accuracy: 0.9937
# Epoch 149/150
# 25/25 [==============================] - 5s 185ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.0192 - val_accuracy: 0.9939
# Epoch 150/150
# 25/25 [==============================] - 5s 186ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.0184 - val_accuracy: 0.9944

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.yscale('log')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.yscale('log')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
NUM_EPOCHS = 50

STEPS_PER_EPOCH = (165 // batch_size) * 5
VALIDATION_STEPS = 1

model_history = unet_model.fit(train_batches,
                              epochs=NUM_EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              validation_steps=VALIDATION_STEPS,
                              callbacks=[callback],
                              validation_data=val_batches)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.1059 - accuracy: 0.9616 - val_loss: 1587.7875 - val_accuracy: 0.9850 - lr: 0.0010
# Epoch 2/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.0367 - accuracy: 0.9871 - val_loss: 22.1768 - val_accuracy: 0.9858 - lr: 0.0010
# Epoch 3/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.0246 - accuracy: 0.9872 - val_loss: 1.1179 - val_accuracy: 0.9855 - lr: 0.0010
# Epoch 4/50
# 15/15 [==============================] - 18s 1s/step - loss: 0.0220 - accuracy: 0.9876 - val_loss: 0.1477 - val_accuracy: 0.9838 - lr: 0.0010
# Epoch 5/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.0202 - accuracy: 0.9902 - val_loss: 0.0979 - val_accuracy: 0.9729 - lr: 0.0010
# Epoch 6/50
# 15/15 [==============================] - 18s 1s/step - loss: 0.0173 - accuracy: 0.9931 - val_loss: 0.1023 - val_accuracy: 0.9544 - lr: 0.0010
# Epoch 7/50
# 15/15 [==============================] - 18s 1s/step - loss: 0.0087 - accuracy: 0.9962 - val_loss: 0.0154 - val_accuracy: 0.9938 - lr: 1.0000e-05
# Epoch 43/50
# 15/15 [==============================] - 18s 1s/step - loss: 0.0088 - accuracy: 0.9962 - val_loss: 0.0150 - val_accuracy: 0.9941 - lr: 1.0000e-05
# Epoch 44/50
# 15/15 [==============================] - 18s 1s/step - loss: 0.0087 - accuracy: 0.9962 - val_loss: 0.0160 - val_accuracy: 0.9937 - lr: 1.0000e-05
# Epoch 45/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.0086 - accuracy: 0.9963 - val_loss: 0.0161 - val_accuracy: 0.9937 - lr: 1.0000e-05
# Epoch 46/50
# 15/15 [==============================] - 18s 1s/step - loss: 0.0087 - accuracy: 0.9962 - val_loss: 0.0158 - val_accuracy: 0.9938 - lr: 1.0000e-05
# Epoch 47/50
# 15/15 [==============================] - 18s 1s/step - loss: 0.0087 - accuracy: 0.9962 - val_loss: 0.0154 - val_accuracy: 0.9941 - lr: 1.0000e-05
# Epoch 48/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.0087 - accuracy: 0.9962 - val_loss: 0.0150 - val_accuracy: 0.9940 - lr: 1.0000e-05
# Epoch 49/50
# 15/15 [==============================] - 20s 1s/step - loss: 0.0088 - accuracy: 0.9962 - val_loss: 0.0165 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 50/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.0087 - accuracy: 0.9962 - val_loss: 0.0156 - val_accuracy: 0.9939 - lr: 1.0000e-05

# %%
def build_unet_model():
    
    inputs = layers.Input(shape=IMG_SIZE + (1,))

    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(inputs, 64)
    # 2 - downsample
    f2, p2 = downsample_block(p1, 128)

    # 5 - bottleneck
    bottleneck = double_conv_block(p2, 512)

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f2, 256)
    # 8 - upsample
    u8 = upsample_block(u6, f1, 64)

    # outputs
    outputs = layers.Conv2D(1, 1, padding="same", activation = "sigmoid")(u8)

    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

    return unet_model

unet_model = build_unet_model()

# %%
print(unet_model.summary())
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 416, 416, 1)]        0         []
#
#  conv2d_92 (Conv2D)          (None, 416, 416, 64)         640       ['input_5[0][0]']
#
#  batch_normalization_84 (Ba  (None, 416, 416, 64)         256       ['conv2d_92[0][0]']
#  tchNormalization)
#
#  activation_64 (Activation)  (None, 416, 416, 64)         0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  conv2d_93 (Conv2D)          (None, 416, 416, 64)         36928     ['activation_64[0][0]']
#
#  max_pooling2d_20 (MaxPooli  (None, 208, 208, 64)         0         ['conv2d_93[0][0]']
#  ng2D)
#
#  batch_normalization_85 (Ba  (None, 208, 208, 64)         256       ['max_pooling2d_20[0][0]']
#  tchNormalization)
#
#  dropout_40 (Dropout)        (None, 208, 208, 64)         0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  conv2d_94 (Conv2D)          (None, 208, 208, 128)        73856     ['dropout_40[0][0]']
#
#  batch_normalization_86 (Ba  (None, 208, 208, 128)        512       ['conv2d_94[0][0]']
#  tchNormalization)
#
#  activation_65 (Activation)  (None, 208, 208, 128)        0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_95 (Conv2D)          (None, 208, 208, 128)        147584    ['activation_65[0][0]']
#
#  max_pooling2d_21 (MaxPooli  (None, 104, 104, 128)        0         ['conv2d_95[0][0]']
#  ng2D)
#
#  batch_normalization_87 (Ba  (None, 104, 104, 128)        512       ['max_pooling2d_21[0][0]']
#  tchNormalization)
#
#  dropout_41 (Dropout)        (None, 104, 104, 128)        0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  conv2d_96 (Conv2D)          (None, 104, 104, 512)        590336    ['dropout_41[0][0]']
#
#  batch_normalization_88 (Ba  (None, 104, 104, 512)        2048      ['conv2d_96[0][0]']
#  tchNormalization)
#
#  activation_66 (Activation)  (None, 104, 104, 512)        0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  conv2d_97 (Conv2D)          (None, 104, 104, 512)        2359808   ['activation_66[0][0]']
#
#  conv2d_transpose_20 (Conv2  (None, 208, 208, 256)        1179904   ['conv2d_97[0][0]']
#  DTranspose)
#
#  batch_normalization_89 (Ba  (None, 208, 208, 256)        1024      ['conv2d_transpose_20[0][0]']
#  tchNormalization)
#
#  activation_67 (Activation)  (None, 208, 208, 256)        0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  concatenate_20 (Concatenat  (None, 208, 208, 384)        0         ['activation_67[0][0]',
#  e)                                                                  'conv2d_95[0][0]']
#
#  dropout_42 (Dropout)        (None, 208, 208, 384)        0         ['concatenate_20[0][0]']
#
#  conv2d_98 (Conv2D)          (None, 208, 208, 256)        884992    ['dropout_42[0][0]']
#
#  batch_normalization_90 (Ba  (None, 208, 208, 256)        1024      ['conv2d_98[0][0]']
#  tchNormalization)
#
#  activation_68 (Activation)  (None, 208, 208, 256)        0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_99 (Conv2D)          (None, 208, 208, 256)        590080    ['activation_68[0][0]']
#
#  conv2d_transpose_21 (Conv2  (None, 416, 416, 64)         147520    ['conv2d_99[0][0]']
#  DTranspose)
#
#  batch_normalization_91 (Ba  (None, 416, 416, 64)         256       ['conv2d_transpose_21[0][0]']
#  tchNormalization)
#
#  activation_69 (Activation)  (None, 416, 416, 64)         0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  concatenate_21 (Concatenat  (None, 416, 416, 128)        0         ['activation_69[0][0]',
#  e)                                                                  'conv2d_93[0][0]']
#
#  dropout_43 (Dropout)        (None, 416, 416, 128)        0         ['concatenate_21[0][0]']
#
#  conv2d_100 (Conv2D)         (None, 416, 416, 64)         73792     ['dropout_43[0][0]']
#
#  batch_normalization_92 (Ba  (None, 416, 416, 64)         256       ['conv2d_100[0][0]']
#  tchNormalization)
#
#  activation_70 (Activation)  (None, 416, 416, 64)         0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  conv2d_101 (Conv2D)         (None, 416, 416, 64)         36928     ['activation_70[0][0]']
#
#  conv2d_102 (Conv2D)         (None, 416, 416, 1)          65        ['conv2d_101[0][0]']
#
# ==================================================================================================
# Total params: 6128577 (23.38 MB)
# Trainable params: 6125505 (23.37 MB)
# Non-trainable params: 3072 (12.00 KB)
# __________________________________________________________________________________________________
# None

# %%
unet_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])#, keras.metrics.MeanIoU(num_classes=2)])

# %%
NUM_EPOCHS = 150

STEPS_PER_EPOCH = (165 // batch_size) * 5
VALIDATION_STEPS = 1

model_history = unet_model.fit(train_batches,
                              epochs=NUM_EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              validation_steps=VALIDATION_STEPS,
                            #   callbacks=[callback],
                              validation_data=val_batches)
# Out:
# Epoch 1/150
# 25/25 [==============================] - 7s 265ms/step - loss: 0.0919 - accuracy: 0.9669 - val_loss: 0.4807 - val_accuracy: 0.9862
# Epoch 2/150
# 25/25 [==============================] - 6s 251ms/step - loss: 0.0316 - accuracy: 0.9873 - val_loss: 0.1606 - val_accuracy: 0.9852
# Epoch 3/150
# 25/25 [==============================] - 6s 251ms/step - loss: 0.0234 - accuracy: 0.9907 - val_loss: 0.1304 - val_accuracy: 0.9858
# Epoch 4/150
# 25/25 [==============================] - 6s 251ms/step - loss: 0.0205 - accuracy: 0.9923 - val_loss: 0.0701 - val_accuracy: 0.9859
# Epoch 5/150
# 25/25 [==============================] - 6s 252ms/step - loss: 0.0185 - accuracy: 0.9928 - val_loss: 0.0859 - val_accuracy: 0.9857
# Epoch 6/150
# 25/25 [==============================] - 6s 250ms/step - loss: 0.0164 - accuracy: 0.9935 - val_loss: 0.0663 - val_accuracy: 0.9870
# Epoch 7/150
# 25/25 [==============================] - 6s 249ms/step - loss: 0.0152 - accuracy: 0.9939 - val_loss: 0.0463 - val_accuracy: 0.9889
# Epoch 8/150
# 25/25 [==============================] - 6s 249ms/step - loss: 0.0151 - accuracy: 0.9940 - val_loss: 0.0385 - val_accuracy: 0.9897
# Epoch 9/150
# 25/25 [==============================] - 6s 252ms/step - loss: 0.0140 - accuracy: 0.9943 - val_loss: 0.0462 - val_accuracy: 0.9891
# Epoch 10/150
# 25/25 [==============================] - 6s 250ms/step - loss: 0.0144 - accuracy: 0.9942 - val_loss: 0.0300 - val_accuracy: 0.9915
# Epoch 11/150
# 25/25 [==============================] - 6s 249ms/step - loss: 0.0142 - accuracy: 0.9942 - val_loss: 0.0298 - val_accuracy: 0.9892
# Epoch 12/150
# 25/25 [==============================] - 6s 249ms/step - loss: 0.0134 - accuracy: 0.9945 - val_loss: 0.0266 - val_accuracy: 0.9918
# Epoch 13/150
# 25/25 [==============================] - 6s 249ms/step - loss: 0.0131 - accuracy: 0.9946 - val_loss: 0.0281 - val_accuracy: 0.9909
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.yscale('log')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
a = next(train_batches)

a[0].shape, a[1].shape
# Out:
# ((9, 832, 832, 1), (16, 832, 832, 1))

# %%
a = next(train_batches)
b = np.where(unet_model.predict(a[0])>0.5, 1, 0)

for i in range(batch_size):
    plt.figure(figsize=(24, 10))
    plt.subplot(1, 2, 1)
    plt.imshow(a[0][i] + 5*b[i], cmap='hot', vmin=-1, vmax=6)
    plt.subplot(1, 2, 2)
    plt.imshow(a[0][i] + 5*a[1][i], cmap='hot', vmin=-1, vmax=6)
    plt.show()
    clear_output(wait=True)
    time.sleep(1)

# %%
a = next(test_generator)
b = np.where(unet_model.predict(a)>0.5, 1, 0)

for i in range(batch_size):
    plt.figure(figsize=(24, 10))
    plt.subplot(1, 2, 1)
    plt.imshow(a[i] + 5*b[i], cmap='hot', vmin=-1, vmax=6)
    plt.subplot(1, 2, 2)
    plt.imshow(a[i], cmap='hot', vmin=-1, vmax=6)
    plt.show()
    clear_output(wait=True)
    time.sleep(.5)

# %%
ind = 6

video = test_data[ind]['video']

video_gray = cv2.resize(video, IMG_SIZE, interpolation = cv2.INTER_LANCZOS4).astype(np.uint8)
video_gray = preprocessing_function(video_gray).transpose(2,0,1)
video_gray = video_gray.reshape(*video_gray.shape, 1)

predictions = unet_model.predict(video_gray, verbose=False).transpose(1,2,0,3)[:,:,:,0]
predictions = cv2.resize(predictions, (video.shape[1], video.shape[0]), interpolation = cv2.INTER_LANCZOS4)
predictions = np.where(predictions>.5, True, False)

for i in range(predictions.shape[2]):
    plt.figure(figsize=(24, 10))
    plt.subplot(1, 2, 1)
    plt.imshow(video[:,:,i]/255 + predictions[:,:,i].astype(bool), cmap='hot', vmin=0, vmax=2)
    plt.subplot(1, 2, 2)
    plt.imshow(video[:,:,i]/255, cmap='hot', vmin=0, vmax=1)
    plt.show()
    clear_output(wait=True)
    # time.sleep(.01)

# %%
predictions_list = []

for d in test_data:

    video = d['video']

    video_gray = cv2.resize(video, IMG_SIZE, interpolation = cv2.INTER_LANCZOS4).astype(np.uint8)
    video_gray = preprocessing_function(video_gray).transpose(2,0,1)
    video_gray = video_gray.reshape(*video_gray.shape, 1)

    predictions = unet_model.predict(video_gray, verbose=False).transpose(1,2,0,3)[:,:,:,0]
    predictions = cv2.resize(predictions, (video.shape[1], video.shape[0]), interpolation = cv2.INTER_LANCZOS4)
    predictions = np.where(predictions>.5, True, False)

    predictions_list.append({
        'name': d['name'],
        'prediction': predictions
        }
    )

# %%
save_zipped_pickle(predictions_list, 'my_predictions2.pkl')
